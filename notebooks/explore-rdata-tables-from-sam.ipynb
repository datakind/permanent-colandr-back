# %%
import pandas as pd

# %%
pd.read_csv('../data/raw/data.outcome.csv')
# Out:
#        Unnamed: 0   aid  Equity Equity_cat      Outcome  \
# 0               1     1       0        NaN      soc_rel
# 1               2     1       0        NaN      soc_rel
# 2               3     1       0        NaN          gov
# 3               4     1       0        NaN          gov
# 4               5     1       0        NaN      soc_rel
# 5               6     1       0        NaN      soc_rel
# 6               7     1       0        NaN          gov
# 7               8     1       0        NaN          gov
# 8               9     2       0        NaN          gov
# 9              10     2       0        NaN          gov
# 10             11     2       0        NaN          gov
# 11             12     2       0        NaN     sub_well
# 12             13     2       0        NaN     sub_well
# 13             14     2       0        NaN     sub_well
# 14             15     2       0        NaN          gov
# 15             16     2       0        NaN          gov
# ...
